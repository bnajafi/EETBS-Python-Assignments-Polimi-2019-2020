# %% [markdown]
# Assignment 8

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
ExternalFilesFolder = r"C:\Users\Nicoletta\GitRepositories\Data-driven_Building_simulation_Polimi_EETBS\Data"
TemperatureFileName = "Austin_weather_2014.csv"
ConsumptionFileName = "consumption_5545.csv"
IrradianceFileName = "irradiance_2014_gen.csv"
pathTemperatureFile = os.path.join(ExternalFilesFolder,TemperatureFileName)
pathConsumptionFile = os.path.join(ExternalFilesFolder,ConsumptionFileName)
pathIrradianceFile = os.path.join(ExternalFilesFolder,IrradianceFileName)

# %%
DF_consumption = pd.read_csv(pathConsumptionFile,sep=",",index_col=0)
DF_consumption
# Out:
#                      air conditioner_5545
# 2014-01-01 06:00:00                   0.0
# 2014-01-01 07:00:00                   0.0
# 2014-01-01 08:00:00                   0.0
# 2014-01-01 09:00:00                   0.0
# 2014-01-01 10:00:00                   0.0
# 2014-01-01 11:00:00                   0.0
# 2014-01-01 12:00:00                   0.0
# 2014-01-01 13:00:00                   0.0
# 2014-01-01 14:00:00                   0.0
# 2014-01-01 15:00:00                   0.0
# 2014-01-01 16:00:00                   0.0
# 2014-01-01 17:00:00                   0.0
# 2014-01-01 18:00:00                   0.0
# 2014-01-01 19:00:00                   0.0
# 2014-01-01 20:00:00                   0.0
# 2014-01-01 21:00:00                   0.0
# 2014-01-01 22:00:00                   0.0
# 2014-01-01 23:00:00                   0.0
# 2014-01-02 00:00:00                   0.0
# 2014-01-02 01:00:00                   0.0
# 2014-01-02 02:00:00                   0.0
# ...

# %%
DF_consumption.index
# Out:
# Index([u'2014-01-01 06:00:00', u'2014-01-01 07:00:00', u'2014-01-01 08:00:00',
#        u'2014-01-01 09:00:00', u'2014-01-01 10:00:00', u'2014-01-01 11:00:00',
#        u'2014-01-01 12:00:00', u'2014-01-01 13:00:00', u'2014-01-01 14:00:00',
#        u'2014-01-01 15:00:00',
#        ...
#        u'2014-12-30 20:00:00', u'2014-12-30 21:00:00', u'2014-12-30 22:00:00',
#        u'2014-12-30 23:00:00', u'2014-12-31 00:00:00', u'2014-12-31 01:00:00',
#        u'2014-12-31 02:00:00', u'2014-12-31 03:00:00', u'2014-12-31 04:00:00',
#        u'2014-12-31 05:00:00'],
#       dtype='object', length=8736)

# %%
oldIndex_consumption = DF_consumption.index
newParsedIndex = pd.to_datetime(oldIndex_consumption)
newParsedIndex
# Out:
# DatetimeIndex(['2014-01-01 06:00:00', '2014-01-01 07:00:00',
#                '2014-01-01 08:00:00', '2014-01-01 09:00:00',
#                '2014-01-01 10:00:00', '2014-01-01 11:00:00',
#                '2014-01-01 12:00:00', '2014-01-01 13:00:00',
#                '2014-01-01 14:00:00', '2014-01-01 15:00:00',
#                ...
#                '2014-12-30 20:00:00', '2014-12-30 21:00:00',
#                '2014-12-30 22:00:00', '2014-12-30 23:00:00',
#                '2014-12-31 00:00:00', '2014-12-31 01:00:00',
#                '2014-12-31 02:00:00', '2014-12-31 03:00:00',
#                '2014-12-31 04:00:00', '2014-12-31 05:00:00'],
#               dtype='datetime64[ns]', length=8736, freq=None)

# %%
DF_consumption.index = newParsedIndex
DF_consumption.head()
# Out:
#                      air conditioner_5545
# 2014-01-01 06:00:00                   0.0
# 2014-01-01 07:00:00                   0.0
# 2014-01-01 08:00:00                   0.0
# 2014-01-01 09:00:00                   0.0
# 2014-01-01 10:00:00                   0.0

# %%
DF_consumption_FirstWeekOfJuly = DF_consumption.loc["2014-07-01 00:00:00":"2014-07-07 00:00:00"]
DF_consumption_FirstWeekOfJuly
# Out:
#                      air conditioner_5545
# 2014-07-01 00:00:00            720.750000
# 2014-07-01 01:00:00            533.666667
# 2014-07-01 02:00:00            492.800000
# 2014-07-01 03:00:00            220.266667
# 2014-07-01 04:00:00            138.483333
# 2014-07-01 05:00:00              0.000000
# 2014-07-01 06:00:00              0.000000
# 2014-07-01 07:00:00              0.000000
# 2014-07-01 08:00:00              0.000000
# 2014-07-01 09:00:00              0.000000
# 2014-07-01 10:00:00              0.000000
# 2014-07-01 11:00:00              0.000000
# 2014-07-01 12:00:00              0.000000
# 2014-07-01 13:00:00            332.500000
# 2014-07-01 14:00:00            603.116667
# 2014-07-01 15:00:00           1060.900000
# 2014-07-01 16:00:00           1591.200000
# 2014-07-01 17:00:00           2667.400000
# 2014-07-01 18:00:00           2603.416667
# 2014-07-01 19:00:00           1777.316667
# 2014-07-01 20:00:00           2468.216667
# ...

# %%
DF_consumption_FirstWeekOfJuly["air conditioner_5545"]
min_conditioner = min(DF_consumption_FirstWeekOfJuly["air conditioner_5545"])
min_conditioner
# Out:
# 0.0

# %%
DF_consumption_FirstWeekOfJuly["air conditioner_5545"]
max_conditioner = max(DF_consumption_FirstWeekOfJuly["air conditioner_5545"])
max_conditioner
# Out:
# 2667.4000000000001

# %%
# %matplotlib notebook

# %%
fig_consumption = plt.figure()
plt.plot(DF_consumption_FirstWeekOfJuly,"-b")
plt.xlabel("Time")
plt.ylabel("AC power (W)")
plt.grid()
plt.legend("Consumption",loc="upper right")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
DF_weather = pd.read_csv(pathTemperatureFile,sep=";",index_col=0)
DF_weather.head()
# Out:
#                          latitude  longitude  tz_offset summary  ozone  \
# localhour
# 2014-01-01 00:00:00-06  30.292432 -97.699662         -6   Clear    NaN
# 2014-01-01 01:00:00-06  30.292432 -97.699662         -6   Clear    NaN
# 2014-01-01 02:00:00-06  30.292432 -97.699662         -6   Clear    NaN
# 2014-01-01 03:00:00-06  30.292432 -97.699662         -6   Clear    NaN
# 2014-01-01 04:00:00-06  30.292432 -97.699662         -6   Clear    NaN
#
#                         ozone_error  temperature  temperature_error  \
# localhour
# 2014-01-01 00:00:00-06          NaN        40.36                NaN
# 2014-01-01 01:00:00-06          NaN        38.11                NaN
# 2014-01-01 02:00:00-06          NaN        38.65                NaN
# 2014-01-01 03:00:00-06          NaN        38.47                NaN
# 2014-01-01 04:00:00-06          NaN        38.00                NaN
#
#                         dew_point  dew_point_error     ...       \
# ...

# %%
oldIndex_weather = DF_weather.index
NewParsedIndex_weather = pd.to_datetime(oldIndex_weather)
DF_weather.index = NewParsedIndex_weather

# %%
DF_temperature = DF_weather[["temperature"]]
DF_temperature_FirstWeekofJuly = DF_temperature["2014-07-01 00:00:00":"2014-07-07 00:00:00"]
DF_temperature_FirstWeekofJuly
# Out:
#                      temperature
# localhour
# 2014-07-01 00:00:00        89.98
# 2014-07-01 01:00:00        86.86
# 2014-07-01 02:00:00        83.71
# 2014-07-01 03:00:00        81.75
# 2014-07-01 04:00:00        78.79
# 2014-07-01 05:00:00        78.34
# 2014-07-01 06:00:00        76.71
# 2014-07-01 07:00:00        75.90
# 2014-07-01 08:00:00        75.91
# 2014-07-01 09:00:00        75.83
# 2014-07-01 10:00:00        75.83
# 2014-07-01 11:00:00        75.59
# 2014-07-01 12:00:00        75.59
# 2014-07-01 13:00:00        76.92
# 2014-07-01 14:00:00        79.80
# 2014-07-01 15:00:00        83.19
# 2014-07-01 16:00:00        86.08
# 2014-07-01 17:00:00        88.53
# 2014-07-01 18:00:00        90.76
# 2014-07-01 19:00:00        92.52
# 2014-07-01 20:00:00        93.91
# 2014-07-01 21:00:00        94.44
# 2014-07-01 22:00:00        94.34
# 2014-07-01 23:00:00        93.15
# 2014-07-02 00:00:00        91.56
# 2014-07-02 01:00:00        88.39
# 2014-07-02 02:00:00        85.71
# ...

# %%
DF_temperature_FirstWeekofJuly["temperature"]
min_temp=min(DF_temperature_FirstWeekofJuly["temperature"])
min_temp
# Out:
# 68.680000000000007

# %%
DF_temperature_FirstWeekofJuly["temperature"]
max_temp = max(DF_temperature_FirstWeekofJuly["temperature"])
max_temp
# Out:
# 94.579999999999998

# %%
fig_temperature = plt.figure()
plt.plot(DF_temperature_FirstWeekofJuly,"-y")
plt.xlabel("Time")
plt.ylabel("Temperature (Cdegree)")
plt.legend("Temperature")
plt.grid()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
DF_irradianceSource = pd.read_csv(pathIrradianceFile,sep=";",index_col=1)
DF_irradiance = DF_irradianceSource[["gen"]]
DF_irradiance.head()
oldIndex_irradiance = DF_irradiance.index
newIndex_irradiance = pd.to_datetime(oldIndex_irradiance)
DF_irradiance.index = newIndex_irradiance

# %%
DF_irradiance_FirstWeekofJuly = DF_irradiance["2014-07-01 00:00:00":"2014-07-07 00:00:00"]
DF_irradiance_FirstWeekofJuly
# Out:
#                           gen
# localhour
# 2014-07-01 00:00:00 -0.005383
# 2014-07-01 01:00:00 -0.005317
# 2014-07-01 02:00:00 -0.005200
# 2014-07-01 03:00:00 -0.005083
# 2014-07-01 04:00:00 -0.005117
# 2014-07-01 05:00:00 -0.005133
# 2014-07-01 06:00:00  0.004583
# 2014-07-01 07:00:00  0.203450
# 2014-07-01 08:00:00  0.712883
# 2014-07-01 09:00:00  1.330883
# 2014-07-01 10:00:00  2.313333
# 2014-07-01 11:00:00  3.335417
# 2014-07-01 12:00:00  3.865817
# 2014-07-01 13:00:00  4.155317
# 2014-07-01 14:00:00  3.995017
# 2014-07-01 15:00:00  3.955133
# 2014-07-01 16:00:00  3.086217
# 2014-07-01 17:00:00  2.609250
# 2014-07-01 18:00:00  1.203500
# 2014-07-01 19:00:00  0.652783
# 2014-07-01 20:00:00  0.038700
# 2014-07-01 21:00:00 -0.005733
# 2014-07-01 22:00:00 -0.005333
# 2014-07-01 23:00:00 -0.005917
# 2014-07-02 00:00:00 -0.005467
# 2014-07-02 01:00:00 -0.005417
# 2014-07-02 02:00:00 -0.005350
# 2014-07-02 03:00:00 -0.005183
# 2014-07-02 04:00:00 -0.005167
# ...

# %%
NegativeCondition = DF_irradiance_FirstWeekofJuly.loc[:,"gen"]<0
NegativeCondition
# Out:
# localhour
# 2014-07-01 00:00:00     True
# 2014-07-01 01:00:00     True
# 2014-07-01 02:00:00     True
# 2014-07-01 03:00:00     True
# 2014-07-01 04:00:00     True
# 2014-07-01 05:00:00     True
# 2014-07-01 06:00:00    False
# 2014-07-01 07:00:00    False
# 2014-07-01 08:00:00    False
# 2014-07-01 09:00:00    False
# 2014-07-01 10:00:00    False
# 2014-07-01 11:00:00    False
# 2014-07-01 12:00:00    False
# 2014-07-01 13:00:00    False
# 2014-07-01 14:00:00    False
# 2014-07-01 15:00:00    False
# 2014-07-01 16:00:00    False
# 2014-07-01 17:00:00    False
# 2014-07-01 18:00:00    False
# 2014-07-01 19:00:00    False
# 2014-07-01 20:00:00    False
# 2014-07-01 21:00:00     True
# 2014-07-01 22:00:00     True
# 2014-07-01 23:00:00     True
# 2014-07-02 00:00:00     True
# 2014-07-02 01:00:00     True
# 2014-07-02 02:00:00     True
# 2014-07-02 03:00:00     True
# 2014-07-02 04:00:00     True
# 2014-07-02 05:00:00     True
#                        ...
# ...

# %%
DF_irradiance_FirstWeekofJuly.loc[NegativeCondition,:] = 0
DF_irradiance.head()
# Out:
# C:\Users\Nicoletta\AppData\Local\Enthought\Canopy\edm\envs\User\lib\site-packages\pandas\core\indexing.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\Nicoletta\AppData\Local\Enthought\Canopy\edm\envs\User\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#                           gen
# localhour
# 2014-01-01 00:00:00 -0.005967
# 2014-01-01 01:00:00 -0.006317
# 2014-01-01 02:00:00 -0.006350
# 2014-01-01 03:00:00 -0.006267
# 2014-01-01 04:00:00 -0.006767

# %%
DF_irradiance_FirstWeekofJuly["gen"]
min_irradiance = min(DF_irradiance_FirstWeekofJuly["gen"])
min_irradiance
# Out:
# 0.0

# %%
DF_irradiance_FirstWeekofJuly["gen"]
max_irradiance = max(DF_irradiance_FirstWeekofJuly["gen"])
max_irradiance
# Out:
# 4.359516666666666

# %%
fig_irradiance = plt.figure()
plt.plot(DF_irradiance_FirstWeekofJuly,"-g")
plt.xlabel("Time")
plt.ylabel("Irradiance (W/m^2)")
plt.legend("Irradiance")
plt.grid()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
DF_joined = DF_consumption_FirstWeekofJuly.join([DF_temperature_FirstWeekofJuly,DF_irradiance_FirstWeekofJuly])
DF_joined.head()
# Out:
#                      air conditioner_5545  temperature  gen
# 2014-07-01 00:00:00            720.750000        89.98  0.0
# 2014-07-01 01:00:00            533.666667        86.86  0.0
# 2014-07-01 02:00:00            492.800000        83.71  0.0
# 2014-07-01 03:00:00            220.266667        81.75  0.0
# 2014-07-01 04:00:00            138.483333        78.79  0.0

# %%
figure_joined, ax=plt.subplots(3)
ax[0].plot(DF_consumption_FirstWeekOfJuly,"-b")
ax[1].plot(DF_temperature_FirstWeekofJuly,"-y")
ax[2].plot(DF_irradiance_FirstWeekofJuly,"-g")
figure_joined
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
whereIwanttosaveMyFile = r"C:\Users\Nicoletta\python4ScientificComputing_Numpy_Pandas_MATPLotLIB-master\A 2019-2020"
figureName1 = "Fig_joined.png"
pathFigure = os.path.join(whereIwanttosaveMyFile,figureName1)
fig.savefig(pathFigure)

# %%
DF_consumption_normalized = (DF_consumption_FirstWeekOfJuly["air conditioner_5545"]-min_conditioner)/(max_conditioner-min_conditioner)
DF_consumption_normalized
# Out:
# 2014-07-01 00:00:00    0.270207
# 2014-07-01 01:00:00    0.200070
# 2014-07-01 02:00:00    0.184749
# 2014-07-01 03:00:00    0.082577
# 2014-07-01 04:00:00    0.051917
# 2014-07-01 05:00:00    0.000000
# 2014-07-01 06:00:00    0.000000
# 2014-07-01 07:00:00    0.000000
# 2014-07-01 08:00:00    0.000000
# 2014-07-01 09:00:00    0.000000
# 2014-07-01 10:00:00    0.000000
# 2014-07-01 11:00:00    0.000000
# 2014-07-01 12:00:00    0.000000
# 2014-07-01 13:00:00    0.124653
# 2014-07-01 14:00:00    0.226107
# 2014-07-01 15:00:00    0.397728
# 2014-07-01 16:00:00    0.596536
# 2014-07-01 17:00:00    1.000000
# 2014-07-01 18:00:00    0.976013
# 2014-07-01 19:00:00    0.666311
# 2014-07-01 20:00:00    0.925327
# 2014-07-01 21:00:00    0.895566
# 2014-07-01 22:00:00    0.801511
# 2014-07-01 23:00:00    0.520601
# 2014-07-02 00:00:00    0.277118
# 2014-07-02 01:00:00    0.228044
# 2014-07-02 02:00:00    0.158638
# 2014-07-02 03:00:00    0.080984
# 2014-07-02 04:00:00    0.078054
# ...

# %%
DF_temperature_normalized = (DF_temperature_FirstWeekofJuly["temperature"]-min_temp)/(max_temp-min_temp)
DF_temperature_normalized
# Out:
# localhour
# 2014-07-01 00:00:00    0.822394
# 2014-07-01 01:00:00    0.701931
# 2014-07-01 02:00:00    0.580309
# 2014-07-01 03:00:00    0.504633
# 2014-07-01 04:00:00    0.390347
# 2014-07-01 05:00:00    0.372973
# 2014-07-01 06:00:00    0.310039
# 2014-07-01 07:00:00    0.278764
# 2014-07-01 08:00:00    0.279151
# 2014-07-01 09:00:00    0.276062
# 2014-07-01 10:00:00    0.276062
# 2014-07-01 11:00:00    0.266795
# 2014-07-01 12:00:00    0.266795
# 2014-07-01 13:00:00    0.318147
# 2014-07-01 14:00:00    0.429344
# 2014-07-01 15:00:00    0.560232
# 2014-07-01 16:00:00    0.671815
# 2014-07-01 17:00:00    0.766409
# 2014-07-01 18:00:00    0.852510
# 2014-07-01 19:00:00    0.920463
# 2014-07-01 20:00:00    0.974131
# 2014-07-01 21:00:00    0.994595
# 2014-07-01 22:00:00    0.990734
# 2014-07-01 23:00:00    0.944788
# 2014-07-02 00:00:00    0.883398
# 2014-07-02 01:00:00    0.761004
# 2014-07-02 02:00:00    0.657529
# 2014-07-02 03:00:00    0.550193
# 2014-07-02 04:00:00    0.451351
# ...

# %%
DF_irradiance_normalized = (DF_irradiance_FirstWeekofJuly["gen"]-min_irradiance)/(max_irradiance-min_irradiance)
DF_irradiance_normalized
# Out:
# localhour
# 2014-07-01 00:00:00    0.000000
# 2014-07-01 01:00:00    0.000000
# 2014-07-01 02:00:00    0.000000
# 2014-07-01 03:00:00    0.000000
# 2014-07-01 04:00:00    0.000000
# 2014-07-01 05:00:00    0.000000
# 2014-07-01 06:00:00    0.001051
# 2014-07-01 07:00:00    0.046668
# 2014-07-01 08:00:00    0.163523
# 2014-07-01 09:00:00    0.305282
# 2014-07-01 10:00:00    0.530640
# 2014-07-01 11:00:00    0.765089
# 2014-07-01 12:00:00    0.886754
# 2014-07-01 13:00:00    0.953160
# 2014-07-01 14:00:00    0.916390
# 2014-07-01 15:00:00    0.907241
# 2014-07-01 16:00:00    0.707926
# 2014-07-01 17:00:00    0.598518
# 2014-07-01 18:00:00    0.276063
# 2014-07-01 19:00:00    0.149738
# 2014-07-01 20:00:00    0.008877
# 2014-07-01 21:00:00    0.000000
# 2014-07-01 22:00:00    0.000000
# 2014-07-01 23:00:00    0.000000
# 2014-07-02 00:00:00    0.000000
# 2014-07-02 01:00:00    0.000000
# 2014-07-02 02:00:00    0.000000
# 2014-07-02 03:00:00    0.000000
# 2014-07-02 04:00:00    0.000000
# ...

# %%
figure_normalized = plt.figure()
plt.plot(DF_consumption_normalized,"-b")
plt.plot(DF_temperature_normalized,"-y")
plt.plot(DF_irradiance_normalized,"-g")
plt.xlabel("Time")
plt.ylabel("Normalized Items")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
whereIwanttosaveMyFile = r"C:\Users\Nicoletta\python4ScientificComputing_Numpy_Pandas_MATPLotLIB-master\A 2019-2020"
figureName2 = "Fig_joined_normalized.png"
pathFigure2 = os.path.join(whereIwanttosaveMyFile,figureName2)
fig.savefig(pathFigure2)
